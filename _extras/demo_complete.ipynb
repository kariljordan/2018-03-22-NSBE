# %% [markdown]
# # Data Management & Visualization with the Carpentries
#
# #### Sarah Brown and Kari Jordan
# #### NSBE 44th Annual Convention
# #### Pittsburgh, PA
# #### March x 2018
#
# #nsbe44 #nsbe44data?

# %% [markdown]
# # Jupyter Notebooks
#
# Combine text and code into one file, interactive
#
# Good for:
#  - research reproducibility
#  - teaching (like this)
#
# Toggle cells between code and markdown

# %%
4+ 3
# Out:
# 7

# %% [markdown]
# Markdown cells can contain LaTeX (nicely formatted math)
#
# $ a^2  + b^2 = c^2$

# %% [markdown]
# Notebooks have extensions called magics that use the notation like this, for example we can make cells like the bash command line

# %%
# %%bash
# cd ../data
# ls
# Out:
# bouldercreek_09_2013.txt
# plots.csv
# portal_mammals.sqlite
# species.csv
# speciesSubset.csv
# survey2001.csv
# survey2002.csv
# surveys.csv
# yearly_files

# %% [markdown]
# We will be using the load magic today to make this workshop go a little faster, by having you all type le

# %%
# %load ../code/example.py
a = 4
b = 5

c = a + b

# %% [markdown]
# # Python basics
#
# we saw calculator above, and did somem quick addition with `example.py`

# %%
print(c)
# Out:
# 9

# %% [markdown]
# Now, use escape to go back to () mode and then with the math cell above highlighted, press c.  Go to the last cell you've used and press v.  This will copy and past the cell for you.  Then modify it to be pythagorean's theorem.

# %%
# %load ../code/example.py
a = 4
b = 5

c = sqrt(a + b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f5cbbb42b505> in <module>()
#       3 b = 5
#       4
# ----> 5 c = sqrt(a + b)
#
# NameError: name 'sqrt' is not defined

# %% [markdown]
# Some math functions are not included, so we use libraries, in this case, it's called `numpy`. So, we'll edit (or copy that cell again)

# %%
import numpy as np # shorter than numpy, common convention
a = 4
b = 5

c = np.sqrt(a + b)

print(c)
# Out:
# 3.0

# %% [markdown]
# # Working with Data
#
# This section will use the `surveys.csv`
#
# You can get a description of it by using
# ```
# %load data_description.md
# ```
#
# in a code cell then changing the cell type to markdown and deleteing the heading line, if you want

# %% [markdown]
# | Column           | Description                        |
# |------------------|------------------------------------|
# | record_id        | Unique id for the observation      |
# | month            | month of observation               |
# | day              | day of observation                 |
# | year             | year of observation                |
# | plot_id          | ID of a particular plot            |
# | species_id       | 2-letter code                      |
# | sex              | sex of animal ("M", "F")           |
# | hindfoot_length  | length of the hindfoot in mm       |
# | weight           | weight of the animal in grams      |

# %% [markdown]
# We will use another library to work with data, called pandas

# %%
import pandas as pd

# %%
pd.read_csv("../data/surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df = pd.read_csv("../data/surveys.csv")

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# There are a bunch of other things that we can do to look at dataframes in a notebook, use the next magic and guess what each will do before trying it by splitting the cell, using `ctrl`,+ `shift` + minus
#
# ```python
# %load df_views.py
# ```

# %%
# %load ../code/df_views.py
surveys_df.head(3)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.month
surveys_df.month.head()
# Out:
# 0    7
# 1    7
# 2    7
# 3    7
# 4    7
# Name: month, dtype: int64

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
# %load ../code/individual_stats.py
# we can also compute the stats individually
# *challenge* modify this cell so that all of these stats print out
surveys_df['weight'].min()
surveys_df['weight'].max()
surveys_df['weight'].mean()
surveys_df['weight'].std()
surveys_df['weight'].count()
# Out:
# 32283

# %% [markdown]
# # Grouped Data
#
# Sometimes we want to split the data by the values in some category and look at statistics

# %%
# remember how the data is organized
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# %load ../code/grouped.py
# Group data by sex
# complete the next row to group data by sex
grouped_data = surveys_df.groupby('sex')
# Compute the summary statistics for all numeric columns by sex
grouped_data.describe()
# Out:
#                     day  hindfoot_length         month       plot_id  \
# sex
# F   count  15690.000000     14894.000000  15690.000000  15690.000000
#     mean      16.007138        28.836780      6.583047     11.440854
#     std        8.271144         9.463789      3.367350      6.870684
#     min        1.000000         7.000000      1.000000      1.000000
#     25%        9.000000        21.000000      4.000000      5.000000
#     50%       16.000000        27.000000      7.000000     12.000000
#     75%       23.000000        36.000000     10.000000     17.000000
#     max       31.000000        64.000000     12.000000     24.000000
# M   count  17348.000000     16476.000000  17348.000000  17348.000000
#     mean      16.184286        29.709578      6.392668     11.098282
#     std        8.199274         9.629246      3.420806      6.728713
#     min        1.000000         2.000000      1.000000      1.000000
# ...

# %%
# Provide the mean for each numeric column by sex
grouped_data.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.583047  16.007138  1990.644997  11.440854
# M    17754.835601  6.392668  16.184286  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %%
# %load ../code/grouped_challenge
# How many recorded individuals are female `F` and how many male `M`
grouped_data['record_id'].count()
# Out:
# sex
# F    15690
# M    17348
# Name: record_id, dtype: int64

# %%
# What happens when you group by two columns using the following syntax and
#    then grab mean values:
grouped_data2 = surveys_df.groupby(['plot_id','sex'])
grouped_data2.mean()
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# plot_id sex
# 1       F    18390.384434  6.597877  15.338443  1990.933962        31.733911
#         M    17197.740639  6.121461  15.905936  1990.091324        34.302770
# 2       F    17714.753608  6.426804  16.288660  1990.449485        30.161220
#         M    18085.458042  6.340035  15.440559  1990.756119        30.353760
# 3       F    19888.783875  6.604703  16.161254  1992.013438        23.774044
#         M    20226.767857  6.271429  16.450000  1992.275000        23.833744
# 4       F    17489.205275  6.442661  15.746560  1990.235092        33.249102
#         M    18493.841748  6.430097  16.507767  1991.000971        34.097959
# 5       F    12280.793169  6.142315  15.722960  1986.485769        28.921844
#         M    12798.426621  6.194539  15.703072  1986.817406        29.694794
# 6       F    19406.503392  6.628223  16.313433  1991.579376        26.981322
# ...

# %%
# Summarize weight values for each plot in your data. HINT: you can use the
#  following syntax to only create summary statistics for one column in your data
by_plot = surveys_df.groupby('plot_id')
by_plot['weight'].describe()
# Out:
# plot_id
# 1        count    1903.000000
#          mean       51.822911
#          std        38.176670
#          min         4.000000
#          25%        30.000000
#          50%        44.000000
#          75%        53.000000
#          max       231.000000
# 2        count    2074.000000
#          mean       52.251688
#          std        46.503602
#          min         5.000000
#          25%        24.000000
#          50%        41.000000
#          75%        50.000000
#          max       278.000000
# 3        count    1710.000000
#          mean       32.654386
#          std        35.641630
#          min         4.000000
#          25%        14.000000
#          50%        23.000000
#          75%        36.000000
#          max       250.000000
# 4        count    1866.000000
#          mean       47.928189
#          std        32.886598
#          min         4.000000
#          25%        30.000000
#          50%        43.000000
#                      ...
# ...

# %% [markdown]
# We can now combine the things we've seen together

# %%
# %load ../code/species_counts
# Count the number of samples by species_id
# hints, use record_id as a column to count
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
# we can also count just a single one
surveys_df.groupby('species_id')['record_id'].count()['DO']
# Out:
# 3027

# %% [markdown]
# # Basic Plotting
# We can do some basic plotting with pandas

# %%
# %load ../code/basic_plot
# Make sure figures appear inline in Ipython Notebook
# %matplotlib inline
# Create a quick bar chart
species_counts.plot(kind='bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()
# Let's plot that too
total_count.plot(kind='bar');

# %%
# %pycat  ../code/data_description.md

# %%
# %load ../code/basic_plot
# Make sure figures appear inline in Ipython Notebook
# %matplotlib inline
# Create a quick bar chart
species_counts.plot(kind='bar');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e04019df5ccd> in <module>()
#       3 get_ipython().magic('matplotlib inline')
#       4 # Create a quick bar chart
# ----> 5 species_counts.plot(kind='bar');
#
# NameError: name 'species_counts' is not defined
